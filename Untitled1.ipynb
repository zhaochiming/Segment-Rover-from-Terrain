# %% [markdown]
# <a href="https://colab.research.google.com/github/zhaochiming/Segment-Rover-from-Terrain/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

from skimage.data import astronaut
from skimage.color import rgb2gray
from skimage.filters import sobel
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float
from PIL import Image, ImageEnhance
from skimage import io
import cv2

img = io.imread('./test.tif')

segments_fz = felzenszwalb(img, scale=700, sigma=0.99, min_size=197,multichannel=True)
segments_slic = slic(img, n_segments=250, compactness=10, sigma=0.2,
                     start_label=1)
gradient = sobel(rgb2gray(img))

print(f'Felzenszwalb number of segments: {len(np.unique(segments_fz))}')
print(f'SLIC number of segments: {len(np.unique(segments_slic))}')


fig, ax = plt.subplots(2, 2, figsize=(10, 10), sharex=True, sharey=True)

ax[0, 0].imshow(mark_boundaries(img, segments_fz))
ax[0, 0].set_title("Felzenszwalbs's method")
ax[0, 1].imshow(mark_boundaries(img, segments_slic))
ax[0, 1].set_title('SLIC')
#plt.imsave('./3fz.jpg',mark_boundaries(img,segments_fz))
#plt.imsave('./3slic.jpg',mark_boundaries(img,segments_slic))

for a in ax.ravel():
    a.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Felzenszwalb number of segments: 136
# SLIC number of segments: 225

# %%
from skimage import data, segmentation, filters, color
from skimage.future import graph
from matplotlib import pyplot as plt
from skimage import io
from skimage.filters import sobel
from skimage import img_as_float
from skimage.segmentation import felzenszwalb, slic, quickshift
from skimage.segmentation import mark_boundaries

from skimage import io

img1 = io.imread('./0fz.jpg')
img2 = io.imread('./0slic.jpg')
img1 = img_as_float(img1[::2, ::2])
img2 = img_as_float(img2[::2, ::2])

segments_quick1 = quickshift(img1, kernel_size=3, max_dist=6, ratio=0.5)
gradient1 = sobel(rgb2gray(img1))
segments_quick2 = quickshift(img2, kernel_size=3, max_dist=6, ratio=0.5)
gradient2 = sobel(rgb2gray(img2))
print(f"Quickshift number of img1 segments: {len(np.unique(segments_quick1))}")
print(f"Quickshift number of img2 segments: {len(np.unique(segments_quick2))}")
fig, ax = plt.subplots(2, 2, figsize=(10, 10), sharex=True, sharey=True)
ax[0, 0].imshow(mark_boundaries(img1, segments_quick1))
ax[0, 0].set_title('Quickshift1')
ax[0, 1].imshow(mark_boundaries(img2, segments_quick2))
ax[0, 1].set_title('Quickshift2')
for a in ax.ravel():
    a.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Quickshift number of img1 segments: 4964
# Quickshift number of img2 segments: 7048

# %%
import matplotlib.pyplot as plt
import numpy as np

from skimage.data import astronaut
from skimage.color import rgb2gray
from skimage.filters import sobel
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float
from skimage import io

img = io.imread('./test1.tif')

segments_fz = felzenszwalb(img, scale=760, sigma=0.8, min_size=360,multichannel=True)
segments_slic = slic(img, n_segments=250, compactness=10, sigma=1,
                     start_label=1)

print(f'Felzenszwalb number of segments: {len(np.unique(segments_fz))}')
print(f'SLIC number of segments: {len(np.unique(segments_slic))}')


fig, ax = plt.subplots(2, 2, figsize=(10, 10), sharex=True, sharey=True)

ax[0, 0].imshow(mark_boundaries(img, segments_fz))
ax[0, 0].set_title("Felzenszwalbs's method")
ax[0, 1].imshow(mark_boundaries(img, segments_slic))
ax[0, 1].set_title('SLIC')


for a in ax.ravel():
    a.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Felzenszwalb number of segments: 113
# SLIC number of segments: 211

# %%
import matplotlib.pyplot as plt
import numpy as np

from skimage.data import astronaut
from skimage.color import rgb2gray
from skimage.filters import sobel
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float
from skimage import io

img = io.imread('./test2.tif')

segments_fz = felzenszwalb(img, scale=760, sigma=0.74, min_size=370,multichannel=True)
segments_slic = slic(img, n_segments=250, compactness=10, sigma=1,
                     start_label=1)
segments_quick = quickshift(img, kernel_size=3, max_dist=6, ratio=0.5)
gradient = sobel(rgb2gray(img))
segments_watershed = watershed(gradient, markers=250, compactness=0.001)

print(f'Felzenszwalb number of segments: {len(np.unique(segments_fz))}')
print(f'SLIC number of segments: {len(np.unique(segments_slic))}')
print(f'Quickshift number of segments: {len(np.unique(segments_quick))}')

fig, ax = plt.subplots(2, 2, figsize=(10, 10), sharex=True, sharey=True)

ax[0, 0].imshow(mark_boundaries(img, segments_fz))
ax[0, 0].set_title("Felzenszwalbs's method")
ax[0, 1].imshow(mark_boundaries(img, segments_slic))
ax[0, 1].set_title('SLIC')


for a in ax.ravel():
    a.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Felzenszwalb number of segments: 150
# SLIC number of segments: 181
# Quickshift number of segments: 7394

# %%
import matplotlib.pyplot as plt
import numpy as np

from skimage.data import astronaut
from skimage.color import rgb2gray
from skimage.filters import sobel
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float
from skimage import io

img = io.imread('./test3.tif')

segments_fz = felzenszwalb(img, scale=750, sigma=0.86, min_size=210,multichannel=True)
segments_slic = slic(img, n_segments=250, compactness=10, sigma=1,
                     start_label=1)
segments_quick = quickshift(img, kernel_size=3, max_dist=6, ratio=0.5)
gradient = sobel(rgb2gray(img))
segments_watershed = watershed(gradient, markers=250, compactness=0.001)

print(f'Felzenszwalb number of segments: {len(np.unique(segments_fz))}')
print(f'SLIC number of segments: {len(np.unique(segments_slic))}')
print(f'Quickshift number of segments: {len(np.unique(segments_quick))}')

fig, ax = plt.subplots(2, 2, figsize=(10, 10), sharex=True, sharey=True)

ax[0, 0].imshow(mark_boundaries(img, segments_fz))
ax[0, 0].set_title("Felzenszwalbs's method")
ax[0, 1].imshow(mark_boundaries(img, segments_slic))
ax[0, 1].set_title('SLIC')


for a in ax.ravel():
    a.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Felzenszwalb number of segments: 177
# SLIC number of segments: 214
# Quickshift number of segments: 5137

# %%
from skimage import data, segmentation, filters, color
from skimage.future import graph
from matplotlib import pyplot as plt
from skimage import io
from skimage.filters import sobel
from skimage import img_as_float
from skimage.segmentation import felzenszwalb, slic, quickshift
from skimage.segmentation import mark_boundaries

img = img_as_float(astronaut()[::2, ::2])

def weight_boundary(graph, src, dst, n):
    """
    Handle merging of nodes of a region boundary region adjacency graph.

    This function computes the `"weight"` and the count `"count"`
    attributes of the edge between `n` and the node formed after
    merging `src` and `dst`.


    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    n : int
        A neighbor of `src` or `dst` or both.

    Returns
    -------
    data : dict
        A dictionary with the "weight" and "count" attributes to be
        assigned for the merged node.

    """
    default = {'weight': 0.0, 'count': 0}

    count_src = graph[src].get(n, default)['count']
    count_dst = graph[dst].get(n, default)['count']

    weight_src = graph[src].get(n, default)['weight']
    weight_dst = graph[dst].get(n, default)['weight']

    count = count_src + count_dst
    return {
        'count': count,
        'weight': (count_src * weight_src + count_dst * weight_dst)/count
    }


def merge_boundary(graph, src, dst):
    """Call back called before merging 2 nodes.

    In this case we don't need to do any computation here.
    """
    pass


img = io.imread('./0fz.jpg')
img = img/255.

edges = filters.sobel(color.rgb2gray(img))
labels = segmentation.slic(img, compactness=35.67, n_segments=125, start_label=1)
g = graph.rag_boundary(labels, edges)

graph.show_rag(labels, g, img)
plt.title('Initial RAG')

labels2 = graph.merge_hierarchical(labels, g, thresh=0.08, rag_copy=False,
                                   in_place_merge=True,
                                   merge_func=merge_boundary,
                                   weight_func=weight_boundary)

graph.show_rag(labels, g, img)
plt.title('RAG after hierarchical merging')

plt.figure()
out = color.label2rgb(labels2, img, kind='avg', bg_label=0)
plt.imshow(out)
plt.title('Final segmentation')

plt.show()

# %%
from skimage import data, segmentation, color
from skimage.future import graph
from matplotlib import pyplot as plt


img = io.imread('./test.tif')

labels1 = segmentation.slic(img, compactness=30, n_segments=400,
                            start_label=1)
out1 = color.label2rgb(labels1, img, kind='avg', bg_label=0)

g = graph.rag_mean_color(img, labels1, mode='similarity')
labels2 = graph.cut_normalized(labels1, g)
out2 = color.label2rgb(labels2, img, kind='avg', bg_label=0)

fig, ax = plt.subplots(nrows=2, sharex=True, sharey=True, figsize=(6, 8))

ax[0].imshow(out1.astype('uint8'))
ax[1].imshow(out2.astype('uint8'))

for a in ax:
    a.axis('off')

plt.tight_layout()
